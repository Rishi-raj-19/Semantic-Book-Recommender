# %%
import pandas as pd

books = pd.read_csv("books_with_categories.csv")

# %%
from transformers import pipeline
classifier = pipeline("text-classification",
                      model="j-hartmann/emotion-english-distilroberta-base",
                      top_k = None,
                      device = -1)
classifier("I love this!")
# Out:
# Device set to use cpu
# [[{'label': 'joy', 'score': 0.9771687984466553},
#   {'label': 'surprise', 'score': 0.008528684265911579},
#   {'label': 'neutral', 'score': 0.005764583125710487},
#   {'label': 'anger', 'score': 0.004419783595949411},
#   {'label': 'sadness', 'score': 0.002092392183840275},
#   {'label': 'disgust', 'score': 0.0016119909705594182},
#   {'label': 'fear', 'score': 0.00041385277290828526}]]

# %%
books["description"][0]
# Out:
# 'A NOVEL THAT READERS and critics have been eagerly anticipating for over a decade, Gilead is an astonishingly imagined story of remarkable lives. John Ames is a preacher, the son of a preacher and the grandson (both maternal and paternal) of preachers. It’s 1956 in Gilead, Iowa, towards the end of the Reverend Ames’s life, and he is absorbed in recording his family’s story, a legacy for the young son he will never see grow up. Haunted by his grandfather’s presence, John tells of the rift between his grandfather and his father: the elder, an angry visionary who fought for the abolitionist cause, and his son, an ardent pacifist. He is troubled, too, by his prodigal namesake, Jack (John Ames) Boughton, his best friend’s lost son who returns to Gilead searching for forgiveness and redemption. Told in John Ames’s joyous, rambling voice that finds beauty, humour and truth in the smallest of life’s details, Gilead is a song of celebration and acceptance of the best and the worst the world has to offer. At its heart is a tale of the sacred bonds between fathers and sons, pitch-perfect in style and story, set to dazzle critics and readers alike.'

# %%
classifier(books["description"][0])
# Out:
# [[{'label': 'fear', 'score': 0.6548405885696411},
#   {'label': 'neutral', 'score': 0.16985228657722473},
#   {'label': 'sadness', 'score': 0.11640921980142593},
#   {'label': 'surprise', 'score': 0.02070065587759018},
#   {'label': 'disgust', 'score': 0.019100677222013474},
#   {'label': 'joy', 'score': 0.01516144908964634},
#   {'label': 'anger', 'score': 0.003935146611183882}]]

# %%
classifier(books["description"][0].split("."))
# Out:
# [[{'label': 'surprise', 'score': 0.7296020984649658},
#   {'label': 'neutral', 'score': 0.14038600027561188},
#   {'label': 'fear', 'score': 0.06816228479146957},
#   {'label': 'joy', 'score': 0.04794260859489441},
#   {'label': 'anger', 'score': 0.009156366810202599},
#   {'label': 'disgust', 'score': 0.0026284765917807817},
#   {'label': 'sadness', 'score': 0.002122163539752364}],
#  [{'label': 'neutral', 'score': 0.44937002658843994},
#   {'label': 'disgust', 'score': 0.27359163761138916},
#   {'label': 'joy', 'score': 0.10908330976963043},
#   {'label': 'sadness', 'score': 0.09362746775150299},
#   {'label': 'anger', 'score': 0.04047830402851105},
#   {'label': 'surprise', 'score': 0.026970159262418747},
#   {'label': 'fear', 'score': 0.006879047024995089}],
#  [{'label': 'neutral', 'score': 0.6462159752845764},
#   {'label': 'sadness', 'score': 0.24273329973220825},
#   {'label': 'disgust', 'score': 0.04342271760106087},
#   {'label': 'surprise', 'score': 0.028300564736127853},
#   {'label': 'joy', 'score': 0.014211472123861313},
#   {'label': 'fear', 'score': 0.0140841044485569},
#   {'label': 'anger', 'score': 0.011031901463866234}],
#  [{'label': 'fear', 'score': 0.9281681180000305},
#   {'label': 'anger', 'score': 0.032191041857004166},
#   {'label': 'neutral', 'score': 0.01280867587774992},
#   {'label': 'sadness', 'score': 0.008756861090660095},
#   {'label': 'surprise', 'score': 0.008597906678915024},
#   {'label': 'disgust', 'score': 0.008431818336248398},
#   {'label': 'joy', 'score': 0.0010455837473273277}],
#  [{'label': 'sadness', 'score': 0.9671575427055359},
#   {'label': 'neutral', 'score': 0.015104127116501331},
#   {'label': 'disgust', 'score': 0.006480589509010315},
#   {'label': 'fear', 'score': 0.005393980070948601},
#   {'label': 'surprise', 'score': 0.002286937553435564},
#   {'label': 'anger', 'score': 0.0018428878393024206},
#   {'label': 'joy', 'score': 0.0017338756006211042}],
#  [{'label': 'joy', 'score': 0.932798445224762},
#   {'label': 'disgust', 'score': 0.0377168171107769},
#   {'label': 'neutral', 'score': 0.015891803428530693},
#   {'label': 'sadness', 'score': 0.006444480270147324},
#   {'label': 'anger', 'score': 0.005024945829063654},
#   {'label': 'surprise', 'score': 0.0015812049387022853},
#   {'label': 'fear', 'score': 0.0005423048860393465}],
#  [{'label': 'joy', 'score': 0.6528708338737488},
#   {'label': 'neutral', 'score': 0.25427478551864624},
#   {'label': 'surprise', 'score': 0.06808284670114517},
#   {'label': 'sadness', 'score': 0.009908987209200859},
#   {'label': 'disgust', 'score': 0.0065122200176119804},
#   {'label': 'anger', 'score': 0.004821304697543383},
#   {'label': 'fear', 'score': 0.0035290175583213568}],
#  [{'label': 'neutral', 'score': 0.5494767427444458},
#   {'label': 'sadness', 'score': 0.11169017851352692},
#   {'label': 'disgust', 'score': 0.10400667786598206},
#   {'label': 'surprise', 'score': 0.07876550406217575},
#   {'label': 'anger', 'score': 0.0641336441040039},
#   {'label': 'fear', 'score': 0.05136283114552498},
#   {'label': 'joy', 'score': 0.04056443274021149}]]

# %%
sentences = books["description"][0].split(".")
predictions = classifier(sentences)

# %%
sentences[0]
# Out:
# 'A NOVEL THAT READERS and critics have been eagerly anticipating for over a decade, Gilead is an astonishingly imagined story of remarkable lives'

# %%
predictions[0]
# Out:
# [{'label': 'surprise', 'score': 0.7296020984649658},
#  {'label': 'neutral', 'score': 0.14038600027561188},
#  {'label': 'fear', 'score': 0.06816228479146957},
#  {'label': 'joy', 'score': 0.04794260859489441},
#  {'label': 'anger', 'score': 0.009156366810202599},
#  {'label': 'disgust', 'score': 0.0026284765917807817},
#  {'label': 'sadness', 'score': 0.002122163539752364}]

# %%
sentences[3]
# Out:
# ' Haunted by his grandfather’s presence, John tells of the rift between his grandfather and his father: the elder, an angry visionary who fought for the abolitionist cause, and his son, an ardent pacifist'

# %%
predictions[3]
# Out:
# [{'label': 'fear', 'score': 0.9281681180000305},
#  {'label': 'anger', 'score': 0.032191041857004166},
#  {'label': 'neutral', 'score': 0.01280867587774992},
#  {'label': 'sadness', 'score': 0.008756861090660095},
#  {'label': 'surprise', 'score': 0.008597906678915024},
#  {'label': 'disgust', 'score': 0.008431818336248398},
#  {'label': 'joy', 'score': 0.0010455837473273277}]

# %%
predictions
# Out:
# [[{'label': 'surprise', 'score': 0.7296020984649658},
#   {'label': 'neutral', 'score': 0.14038600027561188},
#   {'label': 'fear', 'score': 0.06816228479146957},
#   {'label': 'joy', 'score': 0.04794260859489441},
#   {'label': 'anger', 'score': 0.009156366810202599},
#   {'label': 'disgust', 'score': 0.0026284765917807817},
#   {'label': 'sadness', 'score': 0.002122163539752364}],
#  [{'label': 'neutral', 'score': 0.44937002658843994},
#   {'label': 'disgust', 'score': 0.27359163761138916},
#   {'label': 'joy', 'score': 0.10908330976963043},
#   {'label': 'sadness', 'score': 0.09362746775150299},
#   {'label': 'anger', 'score': 0.04047830402851105},
#   {'label': 'surprise', 'score': 0.026970159262418747},
#   {'label': 'fear', 'score': 0.006879047024995089}],
#  [{'label': 'neutral', 'score': 0.6462159752845764},
#   {'label': 'sadness', 'score': 0.24273329973220825},
#   {'label': 'disgust', 'score': 0.04342271760106087},
#   {'label': 'surprise', 'score': 0.028300564736127853},
#   {'label': 'joy', 'score': 0.014211472123861313},
#   {'label': 'fear', 'score': 0.0140841044485569},
#   {'label': 'anger', 'score': 0.011031901463866234}],
#  [{'label': 'fear', 'score': 0.9281681180000305},
#   {'label': 'anger', 'score': 0.032191041857004166},
#   {'label': 'neutral', 'score': 0.01280867587774992},
#   {'label': 'sadness', 'score': 0.008756861090660095},
#   {'label': 'surprise', 'score': 0.008597906678915024},
#   {'label': 'disgust', 'score': 0.008431818336248398},
#   {'label': 'joy', 'score': 0.0010455837473273277}],
#  [{'label': 'sadness', 'score': 0.9671575427055359},
#   {'label': 'neutral', 'score': 0.015104127116501331},
#   {'label': 'disgust', 'score': 0.006480589509010315},
#   {'label': 'fear', 'score': 0.005393980070948601},
#   {'label': 'surprise', 'score': 0.002286937553435564},
#   {'label': 'anger', 'score': 0.0018428878393024206},
#   {'label': 'joy', 'score': 0.0017338756006211042}],
#  [{'label': 'joy', 'score': 0.932798445224762},
#   {'label': 'disgust', 'score': 0.0377168171107769},
#   {'label': 'neutral', 'score': 0.015891803428530693},
#   {'label': 'sadness', 'score': 0.006444480270147324},
#   {'label': 'anger', 'score': 0.005024945829063654},
#   {'label': 'surprise', 'score': 0.0015812049387022853},
#   {'label': 'fear', 'score': 0.0005423048860393465}],
#  [{'label': 'joy', 'score': 0.6528708338737488},
#   {'label': 'neutral', 'score': 0.25427478551864624},
#   {'label': 'surprise', 'score': 0.06808284670114517},
#   {'label': 'sadness', 'score': 0.009908987209200859},
#   {'label': 'disgust', 'score': 0.0065122200176119804},
#   {'label': 'anger', 'score': 0.004821304697543383},
#   {'label': 'fear', 'score': 0.0035290175583213568}],
#  [{'label': 'neutral', 'score': 0.5494767427444458},
#   {'label': 'sadness', 'score': 0.11169017851352692},
#   {'label': 'disgust', 'score': 0.10400667786598206},
#   {'label': 'surprise', 'score': 0.07876550406217575},
#   {'label': 'anger', 'score': 0.0641336441040039},
#   {'label': 'fear', 'score': 0.05136283114552498},
#   {'label': 'joy', 'score': 0.04056443274021149}]]

# %%
sorted(predictions[0], key=lambda x: x["label"])
# Out:
# [{'label': 'anger', 'score': 0.009156366810202599},
#  {'label': 'disgust', 'score': 0.0026284765917807817},
#  {'label': 'fear', 'score': 0.06816228479146957},
#  {'label': 'joy', 'score': 0.04794260859489441},
#  {'label': 'neutral', 'score': 0.14038600027561188},
#  {'label': 'sadness', 'score': 0.002122163539752364},
#  {'label': 'surprise', 'score': 0.7296020984649658}]

# %%
import numpy as np

emotion_labels = ["anger", "disgust", "fear", "joy", "sadness", "surprise", "neutral"]
isbn = []
emotion_scores = {label: [] for label in emotion_labels}

def calculate_max_emotion_scores(predictions):
    per_emotion_scores = {label: [] for label in emotion_labels}
    for prediction in predictions:
        sorted_predictions = sorted(prediction, key=lambda x: x["label"])
        for index, label in enumerate(emotion_labels):
            per_emotion_scores[label].append(sorted_predictions[index]["score"])
    return {label: np.max(scores) for label, scores in per_emotion_scores.items()}

# %%
for i in range(10):
    isbn.append(books["isbn13"][i])
    sentences = books["description"][i].split(".")
    predictions = classifier(sentences)
    max_scores = calculate_max_emotion_scores(predictions)
    for label in emotion_labels:
        emotion_scores[label].append(max_scores[label])

# %%
emotion_scores
# Out:
# {'anger': [0.0641336441040039,
#   0.6126197576522827,
#   0.0641336441040039,
#   0.35148438811302185,
#   0.08141235262155533,
#   0.2322252243757248,
#   0.5381842255592346,
#   0.0641336441040039,
#   0.3006700277328491,
#   0.0641336441040039,
#   0.0641336441040039,
#   0.6126197576522827,
#   0.0641336441040039,
#   0.35148438811302185,
#   0.08141235262155533,
#   0.2322252243757248,
#   0.5381842255592346,
#   0.0641336441040039,
#   0.3006700277328491,
#   0.0641336441040039],
#  'disgust': [0.27359163761138916,
#   0.3482847511768341,
#   0.10400667786598206,
#   0.1507224589586258,
#   0.18449543416500092,
#   0.7271744608879089,
#   0.155854731798172,
#   0.10400667786598206,
#   0.2794816195964813,
#   0.17792661488056183,
#   0.27359163761138916,
#   0.3482847511768341,
#   0.10400667786598206,
#   0.1507224589586258,
#   0.18449543416500092,
#   0.7271744608879089,
#   0.155854731798172,
#   0.10400667786598206,
#   0.2794816195964813,
#   0.17792661488056183],
#  'fear': [0.9281681180000305,
#   0.9425276517868042,
#   0.9723208546638489,
#   0.3607059419155121,
#   0.09504333138465881,
#   0.05136283114552498,
#   0.7474274635314941,
#   0.4044976532459259,
#   0.9155241250991821,
#   0.05136283114552498,
#   0.9281681180000305,
#   0.9425276517868042,
#   0.9723208546638489,
#   0.3607059419155121,
#   0.09504333138465881,
#   0.05136283114552498,
#   0.7474274635314941,
#   0.4044976532459259,
#   0.9155241250991821,
#   0.05136283114552498],
#  'joy': [0.932798445224762,
#   0.7044219970703125,
#   0.7672380805015564,
#   0.2518811821937561,
#   0.04056443274021149,
#   0.043375786393880844,
#   0.872565746307373,
#   0.04056443274021149,
#   0.04056443274021149,
#   0.04056443274021149,
#   0.932798445224762,
#   0.7044219970703125,
#   0.7672380805015564,
#   0.2518811821937561,
#   0.04056443274021149,
#   0.043375786393880844,
#   0.872565746307373,
#   0.04056443274021149,
#   0.04056443274021149,
#   0.04056443274021149],
#  'sadness': [0.6462159752845764,
#   0.8879395127296448,
#   0.5494767427444458,
#   0.7326844930648804,
#   0.8843896985054016,
#   0.621392011642456,
#   0.7121941447257996,
#   0.5494767427444458,
#   0.840289294719696,
#   0.8603722453117371,
#   0.6462159752845764,
#   0.8879395127296448,
#   0.5494767427444458,
#   0.7326844930648804,
#   0.8843896985054016,
#   0.621392011642456,
#   0.7121941447257996,
#   0.5494767427444458,
#   0.840289294719696,
#   0.8603722453117371],
#  'surprise': [0.9671575427055359,
#   0.11169017851352692,
#   0.11169017851352692,
#   0.11169017851352692,
#   0.47588053345680237,
#   0.11169017851352692,
#   0.40800127387046814,
#   0.8202826380729675,
#   0.35446077585220337,
#   0.11169017851352692,
#   0.9671575427055359,
#   0.11169017851352692,
#   0.11169017851352692,
#   0.11169017851352692,
#   0.47588053345680237,
#   0.11169017851352692,
#   0.40800127387046814,
#   0.8202826380729675,
#   0.35446077585220337,
#   0.11169017851352692],
#  'neutral': [0.7296020984649658,
#   0.252546101808548,
#   0.07876550406217575,
#   0.07876550406217575,
#   0.07876550406217575,
#   0.27190330624580383,
#   0.07876550406217575,
#   0.2344866842031479,
#   0.13561423122882843,
#   0.07876550406217575,
#   0.7296020984649658,
#   0.252546101808548,
#   0.07876550406217575,
#   0.07876550406217575,
#   0.07876550406217575,
#   0.27190330624580383,
#   0.07876550406217575,
#   0.2344866842031479,
#   0.13561423122882843,
#   0.07876550406217575]}

# %%
from tqdm import tqdm

emotion_labels = ["anger", "disgust", "fear", "joy", "sadness", "surprise", "neutral"]
isbn = []
emotion_scores = {label: [] for label in emotion_labels}

for i in tqdm(range(len(books))):
    isbn.append(books["isbn13"][i])
    sentences = books["description"][i].split(".")
    predictions = classifier(sentences)
    max_scores = calculate_max_emotion_scores(predictions)
    for label in emotion_labels:
        emotion_scores[label].append(max_scores[label])
# Out:
# 100%|██████████| 5197/5197 [15:10<00:00,  5.71it/s]

# %%
emotions_df = pd.DataFrame(emotion_scores)
emotions_df["isbn13"] = isbn

# %%
emotions_df
# Out:
#          anger   disgust      fear       joy   sadness  surprise   neutral  \
# 0     0.064134  0.273592  0.928168  0.932798  0.646216  0.967158  0.729602
# 1     0.612620  0.348285  0.942528  0.704422  0.887940  0.111690  0.252546
# 2     0.064134  0.104007  0.972321  0.767238  0.549477  0.111690  0.078766
# 3     0.351484  0.150722  0.360706  0.251881  0.732684  0.111690  0.078766
# 4     0.081412  0.184495  0.095043  0.040564  0.884390  0.475881  0.078766
# ...        ...       ...       ...       ...       ...       ...       ...
# 5192  0.148208  0.030643  0.919165  0.255172  0.853721  0.980877  0.030656
# 5193  0.064134  0.114383  0.051363  0.400262  0.883198  0.111690  0.227765
# 5194  0.009997  0.009929  0.339218  0.947779  0.375754  0.066685  0.057625
# 5195  0.064134  0.104007  0.459269  0.759456  0.951104  0.368111  0.078766
# 5196  0.064134  0.104007  0.051363  0.958549  0.915193  0.111690  0.078766
#
#              isbn13
# 0     9780002005883
# 1     9780002261982
# 2     9780006178736
# 3     9780006280897
# 4     9780006280934
# ...             ...
# 5192  9788172235222
# 5193  9788173031014
# 5194  9788179921623
# 5195  9788185300535
# 5196  9789027712059
#
# [5197 rows x 8 columns]

# %%
books = pd.merge(books, emotions_df, on = "isbn13")

# %%
books
# Out:
#              isbn13      isbn10  \
# 0     9780002005883  0002005883
# 1     9780002261982  0002261987
# 2     9780006178736  0006178731
# 3     9780006280897  0006280897
# 4     9780006280934  0006280935
# ...             ...         ...
# 5192  9788172235222  8172235224
# 5193  9788173031014  8173031010
# 5194  9788179921623  817992162X
# 5195  9788185300535  8185300534
# 5196  9789027712059  9027712050
#
#                                                   title  \
# 0                                                Gilead
# 1                                          Spider's Web
# 2                                        Rage of angels
# 3                                        The Four Loves
# 4                                   The Problem of Pain
# ...                                                 ...
# 5192                                  Mistaken Identity
# 5193                                Journey to the East
# 5194  The Monk Who Sold His Ferrari: A Fable About F...
# 5195                                          I Am that
# 5196                           The Berlin Phenomenology
#
#                                            authors  \
# 0                               Marilynne Robinson
# 1                  Charles Osborne;Agatha Christie
# 2                                   Sidney Sheldon
# 3                              Clive Staples Lewis
# 4                              Clive Staples Lewis
# ...                                            ...
# 5192                              Nayantara Sahgal
# 5193                                 Hermann Hesse
# 5194                                  Robin Sharma
# 5195  Sri Nisargadatta Maharaj;Sudhakar S. Dikshit
# 5196                 Georg Wilhelm Friedrich Hegel
#
#                          categories  \
# 0                           Fiction
# 1     Detective and mystery stories
# 2                           Fiction
# 3                    Christian life
# 4                    Christian life
# ...                             ...
# 5192        Indic fiction (English)
# 5193              Adventure stories
# 5194               Health & Fitness
# 5195                     Philosophy
# 5196                        History
#
#                                               thumbnail  \
# 0     http://books.google.com/books/content?id=KQZCP...
# 1     http://books.google.com/books/content?id=gA5GP...
# 2     http://books.google.com/books/content?id=FKo2T...
# 3     http://books.google.com/books/content?id=XhQ5X...
# 4     http://books.google.com/books/content?id=Kk-uV...
# ...                                                 ...
# 5192  http://books.google.com/books/content?id=q-tKP...
# 5193  http://books.google.com/books/content?id=rq6JP...
# 5194  http://books.google.com/books/content?id=c_7mf...
# 5195  http://books.google.com/books/content?id=Fv_JP...
# 5196  http://books.google.com/books/content?id=Vy7Sk...
#
#                                             description  published_year  \
# 0     A NOVEL THAT READERS and critics have been eag...          2004.0
# 1     A new 'Christie for Christmas' -- a full-lengt...          2000.0
# 2     A memorable, mesmerizing heroine Jennifer -- b...          1993.0
# 3     Lewis' work on the nature of love divides love...          2002.0
# 4     "In The Problem of Pain, C.S. Lewis, one of th...          2002.0
# ...                                                 ...             ...
# 5192  On A Train Journey Home To North India After L...          2003.0
# 5193  This book tells the tale of a man who goes on ...          2002.0
# 5194  Wisdom to Create a Life of Passion, Purpose, a...          2003.0
# 5195  This collection of the timeless teachings of o...          1999.0
# 5196  Since the three volume edition ofHegel's Philo...          1981.0
#
#       average_rating  num_pages  ...  \
# 0               3.85      247.0  ...
# 1               3.83      241.0  ...
# 2               3.93      512.0  ...
# 3               4.15      170.0  ...
# 4               4.09      176.0  ...
# ...              ...        ...  ...
# 5192            2.93      324.0  ...
# 5193            3.70      175.0  ...
# 5194            3.82      198.0  ...
# 5195            4.51      531.0  ...
# 5196            0.00      210.0  ...
#
#                                      title_and_subtitle  \
# 0                                                Gilead
# 1                                 Spider's Web: A Novel
# 2                                        Rage of angels
# 3                                        The Four Loves
# 4                                   The Problem of Pain
# ...                                                 ...
# 5192                                  Mistaken Identity
# 5193                                Journey to the East
# 5194  The Monk Who Sold His Ferrari: A Fable About F...
# 5195     I Am that: Talks with Sri Nisargadatta Maharaj
# 5196                           The Berlin Phenomenology
#
#                                      tagged_description simple_categories  \
# 0     9780002005883 A NOVEL THAT READERS and critics...           Fiction
# 1     9780002261982 A new 'Christie for Christmas' -...           Fiction
# 2     9780006178736 A memorable, mesmerizing heroine...           Fiction
# 3     9780006280897 Lewis' work on the nature of lov...        Nonfiction
# 4     9780006280934 "In The Problem of Pain, C.S. Le...        Nonfiction
# ...                                                 ...               ...
# 5192  9788172235222 On A Train Journey Home To North...           Fiction
# 5193  9788173031014 This book tells the tale of a ma...        Nonfiction
# 5194  9788179921623 Wisdom to Create a Life of Passi...           Fiction
# 5195  9788185300535 This collection of the timeless ...        Nonfiction
# 5196  9789027712059 Since the three volume edition o...        Nonfiction
#
#          anger   disgust      fear       joy   sadness  surprise   neutral
# 0     0.064134  0.273592  0.928168  0.932798  0.646216  0.967158  0.729602
# 1     0.612620  0.348285  0.942528  0.704422  0.887940  0.111690  0.252546
# 2     0.064134  0.104007  0.972321  0.767238  0.549477  0.111690  0.078766
# 3     0.351484  0.150722  0.360706  0.251881  0.732684  0.111690  0.078766
# 4     0.081412  0.184495  0.095043  0.040564  0.884390  0.475881  0.078766
# ...        ...       ...       ...       ...       ...       ...       ...
# 5192  0.148208  0.030643  0.919165  0.255172  0.853721  0.980877  0.030656
# 5193  0.064134  0.114383  0.051363  0.400262  0.883198  0.111690  0.227765
# 5194  0.009997  0.009929  0.339218  0.947779  0.375754  0.066685  0.057625
# 5195  0.064134  0.104007  0.459269  0.759456  0.951104  0.368111  0.078766
# 5196  0.064134  0.104007  0.051363  0.958549  0.915193  0.111690  0.078766
#
# [5197 rows x 21 columns]

# %%
books.to_csv("books_with_emotions.csv", index = False)

# %%
pip install -U langchain-huggingface
# Out:
# Collecting langchain-huggingface
#   Downloading langchain_huggingface-0.3.0-py3-none-any.whl.metadata (996 bytes)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.65 in c:\users\rc670\pycharmprojects\book-project\.venv\lib\site-packages (from langchain-huggingface) (0.3.68)
# Requirement already satisfied: tokenizers>=0.19.1 in c:\users\rc670\pycharmprojects\book-project\.venv\lib\site-packages (from langchain-huggingface) (0.21.2)
# Requirement already satisfied: huggingface-hub>=0.30.2 in c:\users\rc670\pycharmprojects\book-project\.venv\lib\site-packages (from langchain-huggingface) (0.33.3)
# Requirement already satisfied: langsmith>=0.3.45 in c:\users\rc670\pycharmprojects\book-project\.venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.65->langchain-huggingface) (0.4.5)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\rc670\pycharmprojects\book-project\.venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.65->langchain-huggingface) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\rc670\pycharmprojects\book-project\.venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.65->langchain-huggingface) (1.33)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\rc670\pycharmprojects\book-project\.venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.65->langchain-huggingface) (6.0.2)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\rc670\pycharmprojects\book-project\.venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.65->langchain-huggingface) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\rc670\pycharmprojects\book-project\.venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.65->langchain-huggingface) (4.14.1)
# Requirement already satisfied: pydantic>=2.7.4 in c:\users\rc670\pycharmprojects\book-project\.venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.65->langchain-huggingface) (2.11.7)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\rc670\pycharmprojects\book-project\.venv\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.65->langchain-huggingface) (3.0.0)
# Requirement already satisfied: filelock in c:\users\rc670\pycharmprojects\book-project\.venv\lib\site-packages (from huggingface-hub>=0.30.2->langchain-huggingface) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\rc670\pycharmprojects\book-project\.venv\lib\site-packages (from huggingface-hub>=0.30.2->langchain-huggingface) (2025.5.1)
# Requirement already satisfied: requests in c:\users\rc670\pycharmprojects\book-project\.venv\lib\site-packages (from huggingface-hub>=0.30.2->langchain-huggingface) (2.32.4)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\rc670\pycharmprojects\book-project\.venv\lib\site-packages (from huggingface-hub>=0.30.2->langchain-huggingface) (4.67.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\rc670\pycharmprojects\book-project\.venv\lib\site-packages (from langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.65->langchain-huggingface) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\rc670\pycharmprojects\book-project\.venv\lib\site-packages (from langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.65->langchain-huggingface) (3.10.18)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\rc670\pycharmprojects\book-project\.venv\lib\site-packages (from langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.65->langchain-huggingface) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\users\rc670\pycharmprojects\book-project\.venv\lib\site-packages (from langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.65->langchain-huggingface) (0.23.0)
# Requirement already satisfied: anyio in c:\users\rc670\pycharmprojects\book-project\.venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.65->langchain-huggingface) (4.9.0)
# Requirement already satisfied: certifi in c:\users\rc670\pycharmprojects\book-project\.venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.65->langchain-huggingface) (2025.7.9)
# Requirement already satisfied: httpcore==1.* in c:\users\rc670\pycharmprojects\book-project\.venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.65->langchain-huggingface) (1.0.9)
# Requirement already satisfied: idna in c:\users\rc670\pycharmprojects\book-project\.venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.65->langchain-huggingface) (3.10)
# Requirement already satisfied: h11>=0.16 in c:\users\rc670\pycharmprojects\book-project\.venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.65->langchain-huggingface) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\rc670\pycharmprojects\book-project\.venv\lib\site-packages (from pydantic>=2.7.4->langchain-core<1.0.0,>=0.3.65->langchain-huggingface) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\rc670\pycharmprojects\book-project\.venv\lib\site-packages (from pydantic>=2.7.4->langchain-core<1.0.0,>=0.3.65->langchain-huggingface) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\rc670\pycharmprojects\book-project\.venv\lib\site-packages (from pydantic>=2.7.4->langchain-core<1.0.0,>=0.3.65->langchain-huggingface) (0.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\rc670\pycharmprojects\book-project\.venv\lib\site-packages (from requests->huggingface-hub>=0.30.2->langchain-huggingface) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\rc670\pycharmprojects\book-project\.venv\lib\site-packages (from requests->huggingface-hub>=0.30.2->langchain-huggingface) (2.5.0)
# Requirement already satisfied: colorama in c:\users\rc670\pycharmprojects\book-project\.venv\lib\site-packages (from tqdm>=4.42.1->huggingface-hub>=0.30.2->langchain-huggingface) (0.4.6)
# Requirement already satisfied: sniffio>=1.1 in c:\users\rc670\pycharmprojects\book-project\.venv\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.65->langchain-huggingface) (1.3.1)
# Downloading langchain_huggingface-0.3.0-py3-none-any.whl (27 kB)
# Installing collected packages: langchain-huggingface
# Successfully installed langchain-huggingface-0.3.0
# Note: you may need to restart the kernel to use updated packages.
